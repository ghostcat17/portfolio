# %% [markdown]
# <a href="https://colab.research.google.com/github/ghostcat17/portfolio/blob/main/final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from keras import optimizers
from keras.models import Model, Sequential
from keras.layers import Dense, Activation
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate, BatchNormalization, Conv1D, Conv2D, Flatten, MaxPooling1D
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Pitt/NoFloats
# Out:
# /content/drive/.shortcut-targets-by-id/1ElGklO6kbzbIVk4xFn_2mkaBxm8I89as/Pitt/NoFloats

# %%
ls
# Out:
# fulle10ppd.pkl  fulle14ppd.pkl  fulle18ppd.pkl  fulle9ppd.pkl   fullmaleppd.pkl
# fulle11ppd.pkl  fulle15ppd.pkl  fulle19ppd.pkl  fullfemppd.pkl  fullmid.pkl
# fulle12ppd.pkl  fulle16ppd.pkl  fulle20ppd.pkl  fullhigh.pkl
# fulle13ppd.pkl  fulle17ppd.pkl  fulle8ppd.pkl   fulllow.pkl

# %%
import gensim
import keras
import pickle

# %%
filename1='fullmid.pkl'
data=pickle.load(open(filename1,'rb')) ###open preprocessed data
data
# Out:
#                                    Transcript   AD            id  sex  educ
# 186                                oh boy exc  1.0  1.000000e+01  1.0  12.0
# 187    wowie boy going cookie jar stool r get  1.0  1.000000e+01  1.0  12.0
# 188    wowie boy going cookie jar stool r get  1.0  1.000000e+01  1.0  12.0
# 189                                hit bottom  1.0  1.000000e+01  1.0  12.0
# 190               mama ov sink overrunning uh  1.0  1.000000e+01  1.0  12.0
# ...                                       ...  ...           ...  ...   ...
# 25889       washing dish and sink overflowing  0.0  2.000018e+09  0.0  15.0
# 25890              and paying attention going  0.0  2.000018e+09  0.0  15.0
# 25891                   it nice kitchen clean  0.0  2.000018e+09  0.0  15.0
# 25892                  nice outside nice yard  0.0  2.000018e+09  0.0  15.0
# 25893                                      it  0.0  2.000018e+09  0.0  15.0
#
# [16939 rows x 5 columns]

# %%
Y= data.iloc[:,1].values
Y
# Out:
# array([1., 1., 1., ..., 0., 0., 0.])

# %%
X = data['Transcript'].tolist()
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, random_state = 0) ##split the data in training and testing
print(X_train) ###length of training, testing data
print(len(X_test))
print(len(Y_train))
print(len(Y_test))
# Out:
# ['xxx foot getting wet', 'see two child trying get cooky cookie jar and', 'yeah', 'still boy boy standing', 'know exc', 'grass', 'using stepstool tipping mother', 'chair stool tipping boy standing', 'sink overflowing water flowing floor', 'standing water', 'sister asking uh something eat', 'boy and girl and woman', 'little girl saying shh something like', 'okay', 'okay', 'dish counter', 'mother must looking window water', 'mother washing drying dish', 'wanna know everything wrong picture eh', 'okey dokey exc', 'hm gonna water floor', 'tipping stool', 'wind picking little and think might hear', 'water overflowing', 'and going give cookie sister', 'and well imagine yeah water', 'boy steal cooky and want', 'well let see exc', 'think third term memory particular', 'and maybe mother drying plate', 'spilling floor gram', 'think cover it', 'it look though end lawn cut grass', 'plate', 'want color laugh', 'look like it summertime', 'passin g it', 'foot standing water', 'window look like it open', 'see window got square know like', 'did hear xxx laugh', 'boy short', 'and it look like it pretty nice outside cause window', 'dish', 'see exc gram', 'shoe', 'laughing', 'cup said cup and plate', 'woman watching wash it spilling', 'several cabinet', 'and little girl saying shh tell mother um and', 'see', 'xxx', 'girl washin g dish gram', 'stool falling', 'shoe untied', 'good bad otherwise', 'tree high flower around it', 'it', 'little girl got dress', 'awful shape', 'see boy gonna fall', 'curtain', 'come sadie', 'okay', 'shrubbery outside window', 'woman dish dishcloth towel', 'alright', 'shelf going way across one', 'oh yes exc', 'dish and cup sitting', 'cheat way', 'okay', 'running sink', 'action exc', 'wiping dish', 'kid trying get cooky', 'boy climbing and taking something cookie jar', 'uh sink overflowing', 'and dish might get falled ed', 'okay', 'it', 'kid stealing cooky water running four woman dish', 'and window open appears open', 'window look like window might open', 'open open', 'know heck doin g though exc', 'window appears open', 'oh', 'want everything described like curtain', 'lady drying dish', 'okay exc', 'uh saying shh think', 'would it', 'and mother letting water run sink', 'and oh stealing cooky', 'and curtain pulled back', 'want name everything wrong everything firstname', 'time', 'make noise mother wi turn around', 'um also quite make going', 'laugh', 'hm know wind blowing', 'look like mom apron', 'cupboard door open', 'apron', 'kitchen sink overflowed', 'xxx', 'it kitchen', 'stool tipping', 'okay', 'it look like little girl might cookie already', 'mother looking kitchen well kitchen', 'dish cabinet top', 'dish apparently done already least', 'it look like nice day outside', 'lady something drying dish sink', 'and mother water coming sink', 'and kid gonna tip', 'okay', 'and f fallin g gram', 'and let see see curtain', 'couple dish counter', 'trying steal cookie', 'see', 'nothing well two cup and plate', 'cup plate', 'standing water', 'and window open looking outside it look like', 'curtain window', 'it sleep it sleep aid', 'child stealing cooky borrowing eating cooky laugh', 'mother looking window', 'well xxx jar and got lid', 'and class understand saying would', 'xxx and find anything else really', 'laugh thing overflow faucet overflowing', 'mother apron', 'hear said it it', 'and got hair shirt and skirt and little dimple', 'and outside nice garden path leading around house', 'xxx', 'got faucet', 'ask people repeat', 'guess see it', 'sink overflowing', 'happening know', 'standing water', 'two cup and saucer sink', 'uh let go mother exc', 'curtain window cute little girl cupboard cabinet', 'looking', 'girl reaching cookie', 'mom oblivious spilling water', 'it overflowing and dripping floor', 'tipping chair', 'and curtain window and window open', 'lady letting water run', 'used lot transcribing psychiatric department', 'and see cupboard kitchen cupboard', 'window open', 'well thanks', 'lady wiping dish', 'and mother drying  ...
# 3388
# 13551
# 3388

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

# %%
def create_tokens(lines):
    tokens = Tokenizer()        ###function to create tokens
    tokens.fit_on_texts(lines)
    return tokens

# %%
train_tokenizer = create_tokens(X_train)

# %%
def encode_sentences(tokens,length,lines):   ###function to pad the data to maximum phrase length
    X=tokens.texts_to_sequences(lines)
    X=pad_sequences(X,length,padding='post')
    return X

# %%
X_train = encode_sentences(train_tokenizer,100, X_train)
X_test = encode_sentences(train_tokenizer,100, X_test)

# %%
print(X_train.shape)   ###check for dimensions
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (13551, 100)
# (3388, 100)
# (13551,)
# (3388,)

# %%
vocab_len= len(train_tokenizer.word_index ) + 1 
vocab_len   ###vocab length
# Out:
# 2221

# %%
from keras.models import Sequential
from keras.layers import Embedding
from keras.layers import Conv1D, LSTM, Bidirectional
from keras.layers import MaxPooling1D
from keras.layers import Flatten
from keras.layers import Dense 
from keras.layers import Dropout
from keras.callbacks import ModelCheckpoint
from keras.constraints import maxnorm
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier

# %%
model = Sequential()
e = Embedding(vocab_len, 100, input_length= 100)
model.add(e)
model.add(Conv1D(filters=128,kernel_size=3,activation='relu',strides= 1, kernel_initializer='he_uniform'))
model.add(MaxPooling1D(pool_size=4))
model.add(Bidirectional(LSTM(20)))
model.add(Dropout(0.2))
model.add(Dense(units = 1, activation = 'sigmoid', kernel_initializer= 'glorot_uniform'))
model.compile(optimizer='Adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
cnn_lstm_history=model.fit(X_train, Y_train, epochs = 25, batch_size = 64, verbose = 1, validation_split = 0.1)
# Out:
# Epoch 1/25
# 191/191 [==============================] - 16s 67ms/step - loss: nan - accuracy: 0.7706 - val_loss: nan - val_accuracy: 0.7596
# Epoch 2/25
# 191/191 [==============================] - 12s 63ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 3/25
# 191/191 [==============================] - 12s 62ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 4/25
# 191/191 [==============================] - 12s 62ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 5/25
# 191/191 [==============================] - 12s 62ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 6/25
# 191/191 [==============================] - 12s 62ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 7/25
# 191/191 [==============================] - 12s 62ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 8/25
# 191/191 [==============================] - 12s 62ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 9/25
# 191/191 [==============================] - 12s 62ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 10/25
# 191/191 [==============================] - 12s 62ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 11/25
# 191/191 [==============================] - 12s 63ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 12/25
# 191/191 [==============================] - 12s 62ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 13/25
# 191/191 [==============================] - 12s 63ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 14/25
# 191/191 [==============================] - 12s 62ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 15/25
# 191/191 [==============================] - 12s 63ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 16/25
# 191/191 [==============================] - 12s 63ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 17/25
# 191/191 [==============================] - 12s 62ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 18/25
# 191/191 [==============================] - 12s 62ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 19/25
# 191/191 [==============================] - 12s 63ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 20/25
# 191/191 [==============================] - 12s 62ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 21/25
# 191/191 [==============================] - 12s 62ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 22/25
# 191/191 [==============================] - 12s 62ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 23/25
# 191/191 [==============================] - 12s 62ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 24/25
# 191/191 [==============================] - 12s 62ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596
# Epoch 25/25
# 191/191 [==============================] - 12s 62ms/step - loss: nan - accuracy: 0.7714 - val_loss: nan - val_accuracy: 0.7596

# %%
keras.utils.plot_model(cnn_lstm_history, show_shapes=True, rankdir="LR")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-a166b8ba68e9> in <module>()
# ----> 1 keras.utils.plot_model(cnn_lstm_history, show_shapes=True, rankdir="LR")
#
# AttributeError: module 'keras.utils' has no attribute 'plot_model'

# %%
filename2='fulllow.pkl'
data=pickle.load(open(filename2,'rb')) ###open preprocessed data

# %%
Y= data.iloc[:,1].values
Y
X = data['Transcript'].tolist()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, random_state = 0) ##split the data in training and testing

# %%
train_tokenizer = create_tokens(X_train)
X_train = encode_sentences(train_tokenizer,100, X_train)
X_test = encode_sentences(train_tokenizer,100, X_test)
vocab_len= len(train_tokenizer.word_index ) + 1 
vocab_len   ###vocab length
# Out:
# 576

# %%
model = Sequential()
e = Embedding(vocab_len, 100, input_length= 100)
model.add(e)
model.add(Conv1D(filters=128,kernel_size=3,activation='relu',strides= 1, kernel_initializer='he_uniform'))
model.add(MaxPooling1D(pool_size=4))
model.add(Bidirectional(LSTM(20)))
model.add(Dropout(0.2))
model.add(Dense(units = 1, activation = 'sigmoid', kernel_initializer= 'glorot_uniform'))
model.compile(optimizer='Adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
cnn_lstm_history2=model.fit(X_train, Y_train, epochs = 25, batch_size = 64, verbose = 1, validation_split = 0.1)
# Out:
# Epoch 1/25
# 15/15 [==============================] - 5s 111ms/step - loss: nan - accuracy: 0.1862 - val_loss: nan - val_accuracy: 0.2115
# Epoch 2/25
# 15/15 [==============================] - 1s 62ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 3/25
# 15/15 [==============================] - 1s 61ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 4/25
# 15/15 [==============================] - 1s 60ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 5/25
# 15/15 [==============================] - 1s 61ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 6/25
# 15/15 [==============================] - 1s 61ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 7/25
# 15/15 [==============================] - 1s 63ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 8/25
# 15/15 [==============================] - 1s 60ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 9/25
# 15/15 [==============================] - 1s 60ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 10/25
# 15/15 [==============================] - 1s 61ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 11/25
# 15/15 [==============================] - 1s 61ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 12/25
# 15/15 [==============================] - 1s 63ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 13/25
# 15/15 [==============================] - 1s 60ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 14/25
# 15/15 [==============================] - 1s 61ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 15/25
# 15/15 [==============================] - 1s 63ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 16/25
# 15/15 [==============================] - 1s 60ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 17/25
# 15/15 [==============================] - 1s 61ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 18/25
# 15/15 [==============================] - 1s 60ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 19/25
# 15/15 [==============================] - 1s 61ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 20/25
# 15/15 [==============================] - 1s 61ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 21/25
# 15/15 [==============================] - 1s 60ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 22/25
# 15/15 [==============================] - 1s 60ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 23/25
# 15/15 [==============================] - 1s 61ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 24/25
# 15/15 [==============================] - 1s 60ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115
# Epoch 25/25
# 15/15 [==============================] - 1s 62ms/step - loss: nan - accuracy: 0.1625 - val_loss: nan - val_accuracy: 0.2115

# %%
from keras.utils.vis_utils import plot_model
import tensorflow as tf
tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True)

# %%
filename3='fullhigh.pkl'
data=pickle.load(open(filename3,'rb')) ###open preprocessed data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-523315bd2be4> in <module>()
#       1 filename3='fullhigh.pkl'
# ----> 2 data=pickle.load(open(filename3,'rb')) ###open preprocessed data
#
# NameError: name 'pickle' is not defined

# %%
Y= data.iloc[:,1].values
X = data['Transcript'].tolist()

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, random_state = 0) ##split the data in training and testing
print(X_train) ###length of training, testing data
print(len(X_test))
print(len(Y_train))
print(len(Y_test))

# %%
train_tokenizer = create_tokens(X_train)
X_train = encode_sentences(train_tokenizer,100, X_train)
X_test = encode_sentences(train_tokenizer,100, X_test)
vocab_len= len(train_tokenizer.word_index ) + 1 
vocab_len   ###vocab length

# %%
model = Sequential()
e = Embedding(vocab_len, 100, input_length= 100)
model.add(e)
model.add(Conv1D(filters=128,kernel_size=3,activation='relu',strides= 1, kernel_initializer='he_uniform'))
model.add(MaxPooling1D(pool_size=4))
model.add(Bidirectional(LSTM(20)))
model.add(Dropout(0.2))
model.add(Dense(units = 1, activation = 'sigmoid', kernel_initializer= 'glorot_uniform'))
model.compile(optimizer='Adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
cnn_lstm_history3=model.fit(X_train, Y_train, epochs = 25, batch_size = 64, verbose = 1, validation_split = 0.1)

# %%
from keras.utils.vis_utils import plot_model
plot_model(cnn_lstm_history3, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-d8c230f85ef8> in <module>()
#       1 from keras.utils.vis_utils import plot_model
# ----> 2 plot_model(cnn_lstm_history3, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
#
# NameError: name 'cnn_lstm_history3' is not defined

# %%
filename1='fullmid.pkl'
data=pickle.load(open(filename1,'rb')) ###open preprocessed data
filename2='fulllow.pkl'
data+=pickle.load(open(filename1,'rb')) ###open preprocessed data
filename3='fullhgih.pkl'
data+=pickle.load(open(filename1,'rb')) ###open preprocessed data

data

# %%
Y= data.iloc[:,1].values
X = data['Transcript'].tolist()

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, random_state = 0) ##split the data in training and testing
print(X_train) ###length of training, testing data
print(len(X_test))
print(len(Y_train))
print(len(Y_test))

# %%
train_tokenizer = create_tokens(X_train)
X_train = encode_sentences(train_tokenizer,100, X_train)
X_test = encode_sentences(train_tokenizer,100, X_test)
vocab_len= len(train_tokenizer.word_index ) + 1 
vocab_len   ###vocab length
X_tr = []
for i in range(len(X_train)):
  X_tr.add([model.predict(X_train[i])])

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from keras import optimizers
from keras.models import Model, Sequential
from keras.layers import Dense, Activation
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate, BatchNormalization, Conv1D, Conv2D, Flatten, MaxPooling1D
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
model = Sequential()
model.add(Dense(3,input_dim=3,activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1,activation='sigmoid',kernel_initializer= 'glorot_uniform'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

import tensorflow as tf
tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True)

# %%
cnn_lstm_historyfinal=model.fit(X_train, Y_train, epochs = 25, batch_size = 64, verbose = 1, validation_split = 0.1)
